# %%
class Cliente(object):
    def __init__(self, nome, CPF):
        self.nome = nome
        self.CPF = CPF
        
    # verifica o estoque disponível de bicicletas
    def verEstoque(self, estoque):
        self.estoque = estoque
    
    def locacaoHora(self, valor = 5, quantidade):
        self.custohora = valor * quantidade
        
    def locacaoDia(self, valor = 25, quantidade):
        self.custodia = valor * quantidade
        
    def locacaoSemana(self, valor = 100, quantidade):
        self.custodia = valor * quantidade
        
    def locacaoFamilia(self, bikes, dias):
        # locacaohora - 30 %
        # locacaoDia - 30 %
        # locacaoSemana - 30 %

# %%
class Loja(object):
    
# Calcular a conta quando o cliente decidir devolver a bicicleta;
# Mostrar o estoque de bicicletas;
# Receber pedidos de aluguéis por hora, diários ou semanais validando a possibilidade com o estoque.

# %%
import calendar
import re                       # ajuda a diminuir os erros por caracteres especiais
from datetime import datetime

#     
def calculoDiasLocacao(dataLocacao):
    data2 = datetime.now().date()
    dataLocacao = #colocar de uma forma que o python calcule os dias 
    dif = data2 - data
    dif = dif.days
    return int(dif)

def dataHoje():
    now = datetime.now()
    return ("%s/%s/%s" % (now.day, now.month, now.year))

def mostraCalendario():
    now = datetime.now()
    cal = calendar.month(now.year, now.month)
    print("Calendário:")
    print(cal)

# %%
calculoDiasLocacao
dataHoje()
mostraCalendario()
# Out:
#   File "<ipython-input-14-c16632f52bc8>", line 1
#     calculoDiasLocacao(01/08/2021)
#                         ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
import re
import time

# Validando

def validaCpf(cpf):
    pass 

def validaEndereco(endereco):
    pass

def validaTelefone(telefone):
    pass

def validaNome(nome, sobrenome):
    pass

def validaData(data):
    try:
        date = time.strptime(data, '%d/%m/%Y')
        return bool(date.tm_year <= (int(time.strftime("%Y")) - 18))
    except:
        return False


def melhoresClientes(locacoes):
    pass

# %%
print('______________________________________')
print('         Projeto 3 Lets Code          ')
print('              RENT A BIKE             ')
print('--------------------------------------')
print('   Created by Daniel and Maurício     ')
print('______________________________________')

# %%
validaData(22/10/2021)
# Out:
# False
